# %%
import sys
import os
exmp='Moscow is from very beautiful city. It is the capital of the Russia.'
Token_sentence=exmp.lower().split()
print(Token_sentence)
# Out:
# ['moscow', 'is', 'from', 'very', 'beautiful', 'city.', 'it', 'is', 'the', 'capital', 'of', 'the', 'russia.']

# %%
filter_sentence=[]
data_path = "C:\\Users\\Maaz Amjad\\Desktop\\aclImd"
for fname in os.listdir(data_path):
        if fname[0] == '.':
            continue
        path = os.path.join(data_path,fname)
        f = open(path,'r')
        print(fname)
        for lines in f:
            print(lines)
            #print(words for words in filter_sentence if words not in lines)
# Out:
# 1-2.txt
# i
#
# me
#
# my
#
# myself
#
# we
#
# our
#
# ours
#
# ourselves
#
# you
#
# your
#
# yours
#
# yourself
#
# yourselves
#
# he
#
# him
#
# his
#
# himself
#
# she
#
# her
#
# hers
#
# herself
#
# it
#
# its
#
# itself
#
# they
#
# them
#
# their
#
# theirs
#
# themselves
#
# what
#
# which
#
# who
#
# whom
#
# this
#
# that
#
# these
#
# those
#
# am
#
# is
#
# are
#
# was
#
# were
#
# be
#
# been
#
# being
#
# have
#
# has
#
# had
#
# having
#
# do
#
# does
#
# did
#
# doing
#
# a
#
# an
#
# the
#
# and
#
# but
#
# if
#
# or
#
# because
#
# as
#
# until
#
# while
#
# of
#
# at
#
# by
#
# for
#
# with
#
# about
#
# against
#
# between
#
# into
#
# through
#
# during
#
# before
#
# after
#
# above
#
# below
#
# to
#
# from
#
# up
#
# down
#
# in
#
# out
#
# on
#
# off
#
# over
#
# under
#
# again
#
# further
#
# then
#
# once
#
# here
#
# there
#
# when
#
# where
#
# why
#
# how
#
# all
#
# any
#
# both
#
# each
#
# few
#
# more
#
# most
#
# other
#
# some
#
# such
#
# no
#
# ...
